# %% [markdown]
# This notebook builds on EDA done here: https://github.com/fractaldatalearning/Capstone2/blob/main/notebooks/eda3_1user_modeling.ipynb

# %%
import pandas as pd
import numpy as np
import os
import random

import matplotlib.pyplot as plt
import seaborn as sns

import collections

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
import category_encoders as ce
from sklearn import metrics

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, GradientBoostingClassifier

from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus

from library.sb_utils import save_file
import json

# %%
# import the original full df, drop  useless/redundant columns, fillna
df = pd.read_csv('../data/processed/full_data_cleaned.csv')
df = df.drop(columns = ['product_id', 'aisle_id', 'department_id', 'eval_set']).copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33819106 entries, 0 to 33819105
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_by_user_sequence  int64
#  3   order_dow               int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   add_to_cart_sequence    int64
#  7   reordered               int64
#  8   product_name            object
#  9   aisle_name              object
#  10  dept_name               object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 2.8+ GB

# %% [markdown]
# Decide what chunk of data to work with for the remainder of the project. Randomly choose users of some quantity to leave me with a df sized to function with the computer. Don't start out separating it into train/test split. My intuition is that cross-row calculations don't count as leakage and negatively impact modeling if I'm adding data that has to do with past orders. If this logic turns out to be inappropriate, I can just come back and split the set into separate users (or into certain orders per user) and re-run any subsequent code.

# %%
# How many total users are there?
len(df['user_id'].unique())
# Out:
# 206209

# %%
# Deal with null values
df['days_since_prior_order'] = df['days_since_prior_order'].fillna(-1)
df.isnull().any()

# %%
# After playing around, I found the computer was able to handle adding 
# rows to a df of appx. 1k users. Randomly select 0.5% of users.

all_users = set(df['user_id'].unique()
users1 = random.sample(list(all_users)), 1031)
df1 = df.loc[df['user_id'].isin(users), :].copy()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164808 entries, 14274 to 33814614
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                164808 non-null  int64
#  1   user_id                 164808 non-null  int64
#  2   order_by_user_sequence  164808 non-null  int64
#  3   order_dow               164808 non-null  int64
#  4   order_hour_of_day       164808 non-null  int64
#  5   days_since_prior_order  154152 non-null  float64
#  6   add_to_cart_sequence    164808 non-null  int64
#  7   reordered               164808 non-null  int64
#  8   product_name            164808 non-null  object
#  9   aisle_name              164808 non-null  object
#  10  dept_name               164808 non-null  object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 15.1+ MB

# %%
# Try going back to repeat and then concatenate to end up with 1-2% 
# of users for further analysis. Everything that comes after row 
# creation should go a bit faster so a larger df should work fine. 

not_users1 = all_users - set(users1)
users2 = random.sample(list(not_users1), 1031)  
df2 = df.loc[df['user_id'].isin(users2), :].copy()

not_users1or2 = not_users1 - users2
users3 = random.sample(list(not_users1or2), 1031)  
df3 = df.loc[df['user_id'].isin(users3), :].copy()

not_users1to3 = not_users1or2 - users3
users4 = random.sample(list(not_users1to3), 1031)  
df4 = df.loc[df['user_id'].isin(users4), :].copy()

# %%
# Renamed this df, df1 while the following cell was running.
# Go back and change the value there. 
# Then, repeat with some more users.

# %%
for user in users:
    # Work with 1 user at a time
    rows_to_work_w = df.loc[df['user_id']==user,:].copy()
    for n in range(2,101):
        
        # Get items from prior order not yet in order n
        prior_order_items = set(rows_to_work_w[rows_to_work_w[
            'order_by_user_sequence']==(n-1)]['product_name'].
                                unique().tolist())
        order_n_items = set(df[df['order_by_user_sequence']==n][
            'product_name'].unique().tolist())
        not_yet_in_n = prior_order_items-order_n_items
        
        # Specify new rows as copies of rows from prior order...
        new_rows = rows_to_work_w.loc[rows_to_work_w[
            'order_by_user_sequence']==(n-1),:].copy()
        # ... where the product was not ordered in order n
        new_rows = new_rows.loc[new_rows['product_name'].isin(
            not_yet_in_n),:].copy()
        
        # Change value of add_to_cart_sequence and reordered to 0
        new_rows['add_to_cart_sequence'] = new_rows[
            'add_to_cart_sequence'].replace(df[
            'add_to_cart_sequence'].unique().tolist(), 0)
        new_rows['reordered'] = new_rows['reordered'].replace(1,0)
        
        # Now change value of order_by_user_sequence from prior to n
        new_rows['order_by_user_sequence'] = new_rows[
            'order_by_user_sequence'].replace((n-1),n)

        # Add these rows to df so they're there when loop goes to 
        # next order_by_user_sequence value of n & 
        # get duplicated to every order thereafter
        df = pd.concat([df, new_rows]) 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 217050 entries, 14274 to 15066991
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                217050 non-null  int64
#  1   user_id                 217050 non-null  int64
#  2   order_by_user_sequence  217050 non-null  int64
#  3   order_dow               217050 non-null  int64
#  4   order_hour_of_day       217050 non-null  int64
#  5   days_since_prior_order  217050 non-null  float64
#  6   add_to_cart_sequence    217050 non-null  int64
#  7   reordered               217050 non-null  int64
#  8   product_name            217050 non-null  object
#  9   aisle_name              217050 non-null  object
#  10  dept_name               217050 non-null  object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 19.9+ MB

# %%
df.sample(10)
# Out:
#           order_id  user_id  order_by_user_sequence  order_dow  \
# 2703009     525117    16594                      16          6
# 23857814   2641094   145325                      12          1
# 13835019   1914486    83994                       4          6
# 7882752    3273099    47971                       8          0
# 21445475   1314492   130576                       3          5
# 3885341     396038    23663                       5          6
# 19371536    246843   117568                       8          1
# 28910759   2821868   176198                       8          4
# 2985702     747058    18286                      45          6
# 24593056   3395611   149851                       4          6
#
#           order_hour_of_day  days_since_prior_order  add_to_cart_sequence  \
# 2703009                  14                    30.0                     0
# 23857814                 18                    16.0                     0
# 13835019                 12                     7.0                     2
# 7882752                  10                    11.0                     0
# 21445475                 22                    26.0                     8
# 3885341                  15                     6.0                    10
# 19371536                  8                     5.0                     0
# 28910759                 15                    10.0                     6
# 2985702                  15                     6.0                     0
# 24593056                 12                    30.0                    11
#
#           reordered                        product_name  \
# 2703009           0   Pepperoni Pizza Frozen Sandwiches
# 23857814          0  Fat Free Small Curd Cottage Cheese
# 13835019          1                Creamy Almond Butter
# 7882752           0           Crunchy Chickpeas Falafel
# 21445475          0                   European Cucumber
# 3885341           1                          Fettuccine
# 19371536          0       Butter with Canola Oil Spread
# 28910759          1                         Large Lemon
# 2985702           0   Organic Thompson Seedless Raisins
# 24593056          1       Yellow Corn Organic Tortillas
#
#                        aisle_name        dept_name
# 2703009   frozen appetizers sides           frozen
# 23857814     other creams cheeses       dairy eggs
# 13835019                  spreads           pantry
# 7882752    fruit vegetable snacks           snacks
# 21445475         fresh vegetables          produce
# 3885341               fresh pasta  dry goods pasta
# 19371536                   butter       dairy eggs
# 28910759             fresh fruits          produce
# 2985702    nuts seeds dried fruit           snacks
# 24593056     tortillas flat bread           bakery

# %%
# This took hours to create. Immediately save as a file and 
# work with that file in a new notebook so I have the ability to 
# restart the kernel without having it take forever to run again.

# %%
users_incorrect_deets = df
datapath = '../data/processed'
save_file(users_incorrect_deets, 'users_incorrect_deets.csv', datapath)
# Out:
# Writing file.  "../data/processed/users_incorrect_deets.csv"

# %%
# Out:
# {(109, 1): {'order_id': 1656765,
#   'user_id': 109,
#   'order_by_user_sequence': 1,
#   'order_dow': 1,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': -1.0},
#  (109, 2): {'order_id': 304607,
#   'user_id': 109,
#   'order_by_user_sequence': 2,
#   'order_dow': 1,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 30.0},
#  (109, 3): {'order_id': 1403849,
#   'user_id': 109,
#   'order_by_user_sequence': 3,
#   'order_dow': 3,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 9.0},
#  (109, 4): {'order_id': 659764,
#   'user_id': 109,
#   'order_by_user_sequence': 4,
#   'order_dow': 2,
#   'order_hour_of_day': 5,
#   'days_since_prior_order': 20.0},
#  (109, 5): {'order_id': 3116901,
#   'user_id': 109,
#   'order_by_user_sequence': 5,
#   'order_dow': 0,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 26.0},
#  (109, 6): {'order_id': 1382150,
#   'user_id': 109,
#   'order_by_user_sequence': 6,
#   'order_dow': 1,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 15.0},
#  (109, 7): {'order_id': 1997693,
#   'user_id': 109,
#   'order_by_user_sequence': 7,
#   'order_dow': 1,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 21.0},
#  (109, 8): {'order_id': 1997693,
#   'user_id': 109,
#   'order_by_user_sequence': 8,
#   'order_dow': 1,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 21.0},
#  (247, 1): {'order_id': 1891460,
#   'user_id': 247,
#   'order_by_user_sequence': 1,
#   'order_dow': 5,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': -1.0},
#  (247, 2): {'order_id': 2206543,
#   'user_id': 247,
#   'order_by_user_sequence': 2,
#   'order_dow': 5,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 7.0},
#  (247, 3): {'order_id': 1851551,
#   'user_id': 247,
#   'order_by_user_sequence': 3,
#   'order_dow': 3,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 12.0},
#  (247, 4): {'order_id': 362389,
#   'user_id': 247,
#   'order_by_user_sequence': 4,
#   'order_dow': 5,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 30.0},
#  (247, 5): {'order_id': 3406038,
#   'user_id': 247,
#   'order_by_user_sequence': 5,
#   'order_dow': 3,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 30.0},
#  (247, 6): {'order_id': 3406038,
#   'user_id': 247,
#   'order_by_user_sequence': 6,
#   'order_dow': 3,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 30.0},
#  (338, 1): {'order_id': 1499933,
#   'user_id': 338,
#   'order_by_user_sequence': 1,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': -1.0},
#  (338, 2): {'order_id': 457064,
#   'user_id': 338,
#   'order_by_user_sequence': 2,
#   'order_dow': 1,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 30.0},
#  (338, 3): {'order_id': 1168549,
#   'user_id': 338,
#   'order_by_user_sequence': 3,
#   'order_dow': 1,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 30.0},
#  (338, 4): {'order_id': 882518,
#   'user_id': 338,
#   'order_by_user_sequence': 4,
#   'order_dow': 6,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 12.0},
#  (338, 5): {'order_id': 1465767,
#   'user_id': 338,
#   'order_by_user_sequence': 5,
#   'order_dow': 4,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 30.0},
#  (338, 6): {'order_id': 1465767,
#   'user_id': 338,
#   'order_by_user_sequence': 6,
#   'order_dow': 4,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 30.0},
#  (1144, 1): {'order_id': 1129773,
#   'user_id': 1144,
#   'order_by_user_sequence': 1,
#   'order_dow': 0,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': -1.0},
#  (1144, 2): {'order_id': 2373641,
#   'user_id': 1144,
#   'order_by_user_sequence': 2,
#   'order_dow': 2,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 23.0},
#  (1144, 3): {'order_id': 435984,
#   'user_id': 1144,
#   'order_by_user_sequence': 3,
#   'order_dow': 6,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 25.0},
#  (1144, 4): {'order_id': 304668,
#   'user_id': 1144,
#   'order_by_user_sequence': 4,
#   'order_dow': 0,
#   'order_hour_of_day': 22,
#   'days_since_prior_order': 30.0},
#  (1144, 5): {'order_id': 304668,
#   'user_id': 1144,
#   'order_by_user_sequence': 5,
#   'order_dow': 0,
#   'order_hour_of_day': 22,
#   'days_since_prior_order': 30.0},
#  (1188, 1): {'order_id': 1376924,
#   'user_id': 1188,
#   'order_by_user_sequence': 1,
#   'order_dow': 0,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': -1.0},
#  (1188, 2): {'order_id': 2928712,
#   'user_id': 1188,
#   'order_by_user_sequence': 2,
#   'order_dow': 6,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 27.0},
#  (1188, 3): {'order_id': 1503627,
#   'user_id': 1188,
#   'order_by_user_sequence': 3,
#   'order_dow': 1,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 9.0},
#  (1188, 4): {'order_id': 2504193,
#   'user_id': 1188,
#   'order_by_user_sequence': 4,
#   'order_dow': 0,
#   'order_hour_of_day': 23,
#   'days_since_prior_order': 6.0},
#  (1188, 5): {'order_id': 65923,
#   'user_id': 1188,
#   'order_by_user_sequence': 5,
#   'order_dow': 5,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 5.0},
#  (1188, 6): {'order_id': 93014,
#   'user_id': 1188,
#   'order_by_user_sequence': 6,
#   'order_dow': 0,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 16.0},
#  (1188, 7): {'order_id': 2183152,
#   'user_id': 1188,
#   'order_by_user_sequence': 7,
#   'order_dow': 0,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 7.0},
#  (1188, 8): {'order_id': 2815047,
#   'user_id': 1188,
#   'order_by_user_sequence': 8,
#   'order_dow': 0,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 0.0},
#  (1188, 9): {'order_id': 3081823,
#   'user_id': 1188,
#   'order_by_user_sequence': 9,
#   'order_dow': 0,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 7.0},
#  (1188, 10): {'order_id': 3337559,
#   'user_id': 1188,
#   'order_by_user_sequence': 10,
#   'order_dow': 0,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 7.0},
#  (1188, 11): {'order_id': 580476,
#   'user_id': 1188,
#   'order_by_user_sequence': 11,
#   'order_dow': 6,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 20.0},
#  (1188, 12): {'order_id': 580476,
#   'user_id': 1188,
#   'order_by_user_sequence': 12,
#   'order_dow': 6,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 20.0},
#  (1225, 1): {'order_id': 2411714,
#   'user_id': 1225,
#   'order_by_user_sequence': 1,
#   'order_dow': 3,
#   'order_hour_of_day': 22,
#   'days_since_prior_order': -1.0},
#  (1225, 2): {'order_id': 2108387,
#   'user_id': 1225,
#   'order_by_user_sequence': 2,
#   'order_dow': 0,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (1225, 3): {'order_id': 1438919,
#   'user_id': 1225,
#   'order_by_user_sequence': 3,
#   'order_dow': 0,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 14.0},
#  (1225, 4): {'order_id': 739346,
#   'user_id': 1225,
#   'order_by_user_sequence': 4,
#   'order_dow': 0,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 30.0},
#  (1225, 5): {'order_id': 3098072,
#   'user_id': 1225,
#   'order_by_user_sequence': 5,
#   'order_dow': 6,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 20.0},
#  (1225, 6): {'order_id': 19305,
#   'user_id': 1225,
#   'order_by_user_sequence': 6,
#   'order_dow': 0,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 15.0},
#  (1225, 7): {'order_id': 2157648,
#   'user_id': 1225,
#   'order_by_user_sequence': 7,
#   'order_dow': 6,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 13.0},
#  (1225, 8): {'order_id': 2970309,
#   'user_id': 1225,
#   'order_by_user_sequence': 8,
#   'order_dow': 6,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 7.0},
#  (1225, 9): {'order_id': 2038815,
#   'user_id': 1225,
#   'order_by_user_sequence': 9,
#   'order_dow': 2,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 3.0},
#  (1225, 10): {'order_id': 2602361,
#   'user_id': 1225,
#   'order_by_user_sequence': 10,
#   'order_dow': 0,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 5.0},
#  (1225, 11): {'order_id': 238320,
#   'user_id': 1225,
#   'order_by_user_sequence': 11,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 22.0},
#  (1225, 12): {'order_id': 1664929,
#   'user_id': 1225,
#   'order_by_user_sequence': 12,
#   'order_dow': 1,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 0.0},
#  (1225, 13): {'order_id': 3379260,
#   'user_id': 1225,
#   'order_by_user_sequence': 13,
#   'order_dow': 5,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 4.0},
#  (1225, 14): {'order_id': 316386,
#   'user_id': 1225,
#   'order_by_user_sequence': 14,
#   'order_dow': 2,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (1225, 15): {'order_id': 3338926,
#   'user_id': 1225,
#   'order_by_user_sequence': 15,
#   'order_dow': 6,
#   'order_hour_of_day': 23,
#   'days_since_prior_order': 4.0},
#  (1225, 16): {'order_id': 2625912,
#   'user_id': 1225,
#   'order_by_user_sequence': 16,
#   'order_dow': 3,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 4.0},
#  (1225, 17): {'order_id': 1497845,
#   'user_id': 1225,
#   'order_by_user_sequence': 17,
#   'order_dow': 1,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 5.0},
#  (1225, 18): {'order_id': 2295839,
#   'user_id': 1225,
#   'order_by_user_sequence': 18,
#   'order_dow': 1,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 28.0},
#  (1225, 19): {'order_id': 2968634,
#   'user_id': 1225,
#   'order_by_user_sequence': 19,
#   'order_dow': 0,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 20.0},
#  (1225, 20): {'order_id': 715837,
#   'user_id': 1225,
#   'order_by_user_sequence': 20,
#   'order_dow': 2,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 30.0},
#  (1225, 21): {'order_id': 1863253,
#   'user_id': 1225,
#   'order_by_user_sequence': 21,
#   'order_dow': 3,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 8.0},
#  (1225, 22): {'order_id': 2989706,
#   'user_id': 1225,
#   'order_by_user_sequence': 22,
#   'order_dow': 4,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 15.0},
#  (1225, 23): {'order_id': 1891639,
#   'user_id': 1225,
#   'order_by_user_sequence': 23,
#   'order_dow': 6,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 2.0},
#  (1225, 24): {'order_id': 2885813,
#   'user_id': 1225,
#   'order_by_user_sequence': 24,
#   'order_dow': 0,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 8.0},
#  (1225, 25): {'order_id': 2729920,
#   'user_id': 1225,
#   'order_by_user_sequence': 25,
#   'order_dow': 0,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 14.0},
#  (1225, 26): {'order_id': 2570986,
#   'user_id': 1225,
#   'order_by_user_sequence': 26,
#   'order_dow': 0,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 7.0},
#  (1225, 27): {'order_id': 2570986,
#   'user_id': 1225,
#   'order_by_user_sequence': 27,
#   'order_dow': 0,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 7.0},
#  (1413, 1): {'order_id': 2588121,
#   'user_id': 1413,
#   'order_by_user_sequence': 1,
#   'order_dow': 1,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': -1.0},
#  (1413, 2): {'order_id': 477769,
#   'user_id': 1413,
#   'order_by_user_sequence': 2,
#   'order_dow': 5,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 4.0},
#  (1413, 3): {'order_id': 3092346,
#   'user_id': 1413,
#   'order_by_user_sequence': 3,
#   'order_dow': 1,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 3.0},
#  (1413, 4): {'order_id': 3062163,
#   'user_id': 1413,
#   'order_by_user_sequence': 4,
#   'order_dow': 6,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 12.0},
#  (1413, 5): {'order_id': 22388,
#   'user_id': 1413,
#   'order_by_user_sequence': 5,
#   'order_dow': 5,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 6.0},
#  (1413, 6): {'order_id': 2996400,
#   'user_id': 1413,
#   'order_by_user_sequence': 6,
#   'order_dow': 3,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 5.0},
#  (1413, 7): {'order_id': 147337,
#   'user_id': 1413,
#   'order_by_user_sequence': 7,
#   'order_dow': 1,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 5.0},
#  (1413, 8): {'order_id': 1233409,
#   'user_id': 1413,
#   'order_by_user_sequence': 8,
#   'order_dow': 0,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 6.0},
#  (1413, 9): {'order_id': 1233409,
#   'user_id': 1413,
#   'order_by_user_sequence': 9,
#   'order_dow': 0,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 6.0},
#  (1474, 1): {'order_id': 2934662,
#   'user_id': 1474,
#   'order_by_user_sequence': 1,
#   'order_dow': 0,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': -1.0},
#  (1474, 2): {'order_id': 980753,
#   'user_id': 1474,
#   'order_by_user_sequence': 2,
#   'order_dow': 5,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 30.0},
#  (1474, 3): {'order_id': 3294509,
#   'user_id': 1474,
#   'order_by_user_sequence': 3,
#   'order_dow': 5,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 14.0},
#  (1474, 4): {'order_id': 75468,
#   'user_id': 1474,
#   'order_by_user_sequence': 4,
#   'order_dow': 0,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 16.0},
#  (1474, 5): {'order_id': 2564174,
#   'user_id': 1474,
#   'order_by_user_sequence': 5,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 30.0},
#  (1474, 6): {'order_id': 1732792,
#   'user_id': 1474,
#   'order_by_user_sequence': 6,
#   'order_dow': 6,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 30.0},
#  (1474, 7): {'order_id': 2861813,
#   'user_id': 1474,
#   'order_by_user_sequence': 7,
#   'order_dow': 5,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 27.0},
#  (1474, 8): {'order_id': 1116078,
#   'user_id': 1474,
#   'order_by_user_sequence': 8,
#   'order_dow': 6,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 15.0},
#  (1474, 9): {'order_id': 481964,
#   'user_id': 1474,
#   'order_by_user_sequence': 9,
#   'order_dow': 6,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 7.0},
#  (1474, 10): {'order_id': 481964,
#   'user_id': 1474,
#   'order_by_user_sequence': 10,
#   'order_dow': 6,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 7.0},
#  (1776, 1): {'order_id': 315969,
#   'user_id': 1776,
#   'order_by_user_sequence': 1,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': -1.0},
#  (1776, 2): {'order_id': 260231,
#   'user_id': 1776,
#   'order_by_user_sequence': 2,
#   'order_dow': 5,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 7.0},
#  (1776, 3): {'order_id': 2018593,
#   'user_id': 1776,
#   'order_by_user_sequence': 3,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 7.0},
#  (1776, 4): {'order_id': 656645,
#   'user_id': 1776,
#   'order_by_user_sequence': 4,
#   'order_dow': 5,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 7.0},
#  (1776, 5): {'order_id': 2559273,
#   'user_id': 1776,
#   'order_by_user_sequence': 5,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (1776, 6): {'order_id': 2686808,
#   'user_id': 1776,
#   'order_by_user_sequence': 6,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 10.0},
#  (1776, 7): {'order_id': 1960021,
#   'user_id': 1776,
#   'order_by_user_sequence': 7,
#   'order_dow': 3,
#   'order_hour_of_day': 22,
#   'days_since_prior_order': 2.0},
#  (1776, 8): {'order_id': 1768874,
#   'user_id': 1776,
#   'order_by_user_sequence': 8,
#   'order_dow': 0,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 4.0},
#  (1776, 9): {'order_id': 1452128,
#   'user_id': 1776,
#   'order_by_user_sequence': 9,
#   'order_dow': 5,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 5.0},
#  (1776, 10): {'order_id': 2249647,
#   'user_id': 1776,
#   'order_by_user_sequence': 10,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (1776, 11): {'order_id': 2754579,
#   'user_id': 1776,
#   'order_by_user_sequence': 11,
#   'order_dow': 5,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 28.0},
#  (1776, 12): {'order_id': 798039,
#   'user_id': 1776,
#   'order_by_user_sequence': 12,
#   'order_dow': 4,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 30.0},
#  (1776, 13): {'order_id': 3183132,
#   'user_id': 1776,
#   'order_by_user_sequence': 13,
#   'order_dow': 2,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 5.0},
#  (1776, 14): {'order_id': 528896,
#   'user_id': 1776,
#   'order_by_user_sequence': 14,
#   'order_dow': 3,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 1.0},
#  (1776, 15): {'order_id': 2688021,
#   'user_id': 1776,
#   'order_by_user_sequence': 15,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 9.0},
#  (1776, 16): {'order_id': 1112581,
#   'user_id': 1776,
#   'order_by_user_sequence': 16,
#   'order_dow': 5,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 0.0},
#  (1776, 17): {'order_id': 2191937,
#   'user_id': 1776,
#   'order_by_user_sequence': 17,
#   'order_dow': 3,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 5.0},
#  (1776, 18): {'order_id': 1356602,
#   'user_id': 1776,
#   'order_by_user_sequence': 18,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 2.0},
#  (1776, 19): {'order_id': 2157799,
#   'user_id': 1776,
#   'order_by_user_sequence': 19,
#   'order_dow': 5,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 0.0},
#  (1776, 20): {'order_id': 885770,
#   'user_id': 1776,
#   'order_by_user_sequence': 20,
#   'order_dow': 3,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 5.0},
#  (1776, 21): {'order_id': 579026,
#   'user_id': 1776,
#   'order_by_user_sequence': 21,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 2.0},
#  (1776, 22): {'order_id': 1462059,
#   'user_id': 1776,
#   'order_by_user_sequence': 22,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 0.0},
#  (1776, 23): {'order_id': 609506,
#   'user_id': 1776,
#   'order_by_user_sequence': 23,
#   'order_dow': 3,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 5.0},
#  (1776, 24): {'order_id': 2589527,
#   'user_id': 1776,
#   'order_by_user_sequence': 24,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 2.0},
#  (1776, 25): {'order_id': 1832594,
#   'user_id': 1776,
#   'order_by_user_sequence': 25,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 0.0},
#  (1776, 26): {'order_id': 2561162,
#   'user_id': 1776,
#   'order_by_user_sequence': 26,
#   'order_dow': 1,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 3.0},
#  (1776, 27): {'order_id': 1386170,
#   'user_id': 1776,
#   'order_by_user_sequence': 27,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 3.0},
#  (1776, 28): {'order_id': 3303076,
#   'user_id': 1776,
#   'order_by_user_sequence': 28,
#   'order_dow': 5,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 1.0},
#  (1776, 29): {'order_id': 1684999,
#   'user_id': 1776,
#   'order_by_user_sequence': 29,
#   'order_dow': 5,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 0.0},
#  (1776, 30): {'order_id': 2055228,
#   'user_id': 1776,
#   'order_by_user_sequence': 30,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 3.0},
#  (1776, 31): {'order_id': 1088173,
#   'user_id': 1776,
#   'order_by_user_sequence': 31,
#   'order_dow': 5,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 4.0},
#  (1776, 32): {'order_id': 3331565,
#   'user_id': 1776,
#   'order_by_user_sequence': 32,
#   'order_dow': 1,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 3.0},
#  (1776, 33): {'order_id': 1838920,
#   'user_id': 1776,
#   'order_by_user_sequence': 33,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 3.0},
#  (1776, 34): {'order_id': 1902765,
#   'user_id': 1776,
#   'order_by_user_sequence': 34,
#   'order_dow': 2,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 5.0},
#  (1776, 35): {'order_id': 1183719,
#   'user_id': 1776,
#   'order_by_user_sequence': 35,
#   'order_dow': 3,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 1.0},
#  (1776, 36): {'order_id': 1505100,
#   'user_id': 1776,
#   'order_by_user_sequence': 36,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 2.0},
#  (1776, 37): {'order_id': 814433,
#   'user_id': 1776,
#   'order_by_user_sequence': 37,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 7.0},
#  (1776, 38): {'order_id': 2885512,
#   'user_id': 1776,
#   'order_by_user_sequence': 38,
#   'order_dow': 2,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 4.0},
#  (1776, 39): {'order_id': 1612518,
#   'user_id': 1776,
#   'order_by_user_sequence': 39,
#   'order_dow': 3,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 1.0},
#  (1776, 40): {'order_id': 1397682,
#   'user_id': 1776,
#   'order_by_user_sequence': 40,
#   'order_dow': 3,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 7.0},
#  (1776, 41): {'order_id': 952725,
#   'user_id': 1776,
#   'order_by_user_sequence': 41,
#   'order_dow': 5,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 9.0},
#  (1776, 42): {'order_id': 2466379,
#   'user_id': 1776,
#   'order_by_user_sequence': 42,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (1776, 43): {'order_id': 483982,
#   'user_id': 1776,
#   'order_by_user_sequence': 43,
#   'order_dow': 1,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 3.0},
#  (1776, 44): {'order_id': 218612,
#   'user_id': 1776,
#   'order_by_user_sequence': 44,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 4.0},
#  (1776, 45): {'order_id': 2405902,
#   'user_id': 1776,
#   'order_by_user_sequence': 45,
#   'order_dow': 5,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 0.0},
#  (1776, 46): {'order_id': 660838,
#   'user_id': 1776,
#   'order_by_user_sequence': 46,
#   'order_dow': 2,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 18.0},
#  (1776, 47): {'order_id': 1618347,
#   'user_id': 1776,
#   'order_by_user_sequence': 47,
#   'order_dow': 1,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 6.0},
#  (1776, 48): {'order_id': 2176325,
#   'user_id': 1776,
#   'order_by_user_sequence': 48,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 4.0},
#  (1776, 49): {'order_id': 986493,
#   'user_id': 1776,
#   'order_by_user_sequence': 49,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 0.0},
#  (1776, 50): {'order_id': 891601,
#   'user_id': 1776,
#   'order_by_user_sequence': 50,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (1776, 51): {'order_id': 2093478,
#   'user_id': 1776,
#   'order_by_user_sequence': 51,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 3.0},
#  (1776, 52): {'order_id': 1902945,
#   'user_id': 1776,
#   'order_by_user_sequence': 52,
#   'order_dow': 1,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 0.0},
#  (1776, 53): {'order_id': 2328590,
#   'user_id': 1776,
#   'order_by_user_sequence': 53,
#   'order_dow': 5,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 4.0},
#  (1776, 54): {'order_id': 2703250,
#   'user_id': 1776,
#   'order_by_user_sequence': 54,
#   'order_dow': 5,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 0.0},
#  (1776, 55): {'order_id': 3010523,
#   'user_id': 1776,
#   'order_by_user_sequence': 55,
#   'order_dow': 3,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 5.0},
#  (1776, 56): {'order_id': 421245,
#   'user_id': 1776,
#   'order_by_user_sequence': 56,
#   'order_dow': 4,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 1.0},
#  (1776, 57): {'order_id': 2496254,
#   'user_id': 1776,
#   'order_by_user_sequence': 57,
#   'order_dow': 5,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 1.0},
#  (1776, 58): {'order_id': 1754251,
#   'user_id': 1776,
#   'order_by_user_sequence': 58,
#   'order_dow': 3,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 5.0},
#  (1776, 59): {'order_id': 2379749,
#   'user_id': 1776,
#   'order_by_user_sequence': 59,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 2.0},
#  (1776, 60): {'order_id': 2706722,
#   'user_id': 1776,
#   'order_by_user_sequence': 60,
#   'order_dow': 2,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (1776, 61): {'order_id': 1141405,
#   'user_id': 1776,
#   'order_by_user_sequence': 61,
#   'order_dow': 5,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 3.0},
#  (1776, 62): {'order_id': 2363750,
#   'user_id': 1776,
#   'order_by_user_sequence': 62,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 6.0},
#  (1776, 63): {'order_id': 805557,
#   'user_id': 1776,
#   'order_by_user_sequence': 63,
#   'order_dow': 1,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 4.0},
#  (1776, 64): {'order_id': 3255041,
#   'user_id': 1776,
#   'order_by_user_sequence': 64,
#   'order_dow': 1,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (1776, 65): {'order_id': 2513686,
#   'user_id': 1776,
#   'order_by_user_sequence': 65,
#   'order_dow': 2,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 1.0},
#  (1776, 66): {'order_id': 2816463,
#   'user_id': 1776,
#   'order_by_user_sequence': 66,
#   'order_dow': 4,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 2.0},
#  (1776, 67): {'order_id': 1788931,
#   'user_id': 1776,
#   'order_by_user_sequence': 67,
#   'order_dow': 4,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 0.0},
#  (1776, 68): {'order_id': 104677,
#   'user_id': 1776,
#   'order_by_user_sequence': 68,
#   'order_dow': 4,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (1776, 69): {'order_id': 2588807,
#   'user_id': 1776,
#   'order_by_user_sequence': 69,
#   'order_dow': 5,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 1.0},
#  (1776, 70): {'order_id': 1786641,
#   'user_id': 1776,
#   'order_by_user_sequence': 70,
#   'order_dow': 2,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 4.0},
#  (1776, 71): {'order_id': 2062934,
#   'user_id': 1776,
#   'order_by_user_sequence': 71,
#   'order_dow': 4,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 2.0},
#  (1776, 72): {'order_id': 1325302,
#   'user_id': 1776,
#   'order_by_user_sequence': 72,
#   'order_dow': 4,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 7.0},
#  (1776, 73): {'order_id': 896292,
#   'user_id': 1776,
#   'order_by_user_sequence': 73,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 1.0},
#  (1776, 74): {'order_id': 634917,
#   'user_id': 1776,
#   'order_by_user_sequence': 74,
#   'order_dow': 2,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (1776, 75): {'order_id': 2585593,
#   'user_id': 1776,
#   'order_by_user_sequence': 75,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 3.0},
#  (1776, 76): {'order_id': 46504,
#   'user_id': 1776,
#   'order_by_user_sequence': 76,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 6.0},
#  (1776, 77): {'order_id': 2232224,
#   'user_id': 1776,
#   'order_by_user_sequence': 77,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (1776, 78): {'order_id': 1904172,
#   'user_id': 1776,
#   'order_by_user_sequence': 78,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 4.0},
#  (1776, 79): {'order_id': 1157846,
#   'user_id': 1776,
#   'order_by_user_sequence': 79,
#   'order_dow': 6,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 1.0},
#  (1776, 80): {'order_id': 1006838,
#   'user_id': 1776,
#   'order_by_user_sequence': 80,
#   'order_dow': 6,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 0.0},
#  (1776, 81): {'order_id': 1619779,
#   'user_id': 1776,
#   'order_by_user_sequence': 81,
#   'order_dow': 2,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 3.0},
#  (1776, 82): {'order_id': 155274,
#   'user_id': 1776,
#   'order_by_user_sequence': 82,
#   'order_dow': 4,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 2.0},
#  (1776, 83): {'order_id': 2777518,
#   'user_id': 1776,
#   'order_by_user_sequence': 83,
#   'order_dow': 4,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 0.0},
#  (1776, 84): {'order_id': 2777518,
#   'user_id': 1776,
#   'order_by_user_sequence': 84,
#   'order_dow': 4,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 0.0},
#  (2318, 1): {'order_id': 2376202,
#   'user_id': 2318,
#   'order_by_user_sequence': 1,
#   'order_dow': 3,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': -1.0},
#  (2318, 2): {'order_id': 1417415,
#   'user_id': 2318,
#   'order_by_user_sequence': 2,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 23.0},
#  (2318, 3): {'order_id': 3178476,
#   'user_id': 2318,
#   'order_by_user_sequence': 3,
#   'order_dow': 4,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 6.0},
#  (2318, 4): {'order_id': 1492457,
#   'user_id': 2318,
#   'order_by_user_sequence': 4,
#   'order_dow': 5,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 29.0},
#  (2318, 5): {'order_id': 1492457,
#   'user_id': 2318,
#   'order_by_user_sequence': 5,
#   'order_dow': 5,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 29.0},
#  (2329, 1): {'order_id': 957436,
#   'user_id': 2329,
#   'order_by_user_sequence': 1,
#   'order_dow': 2,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': -1.0},
#  (2329, 2): {'order_id': 2593861,
#   'user_id': 2329,
#   'order_by_user_sequence': 2,
#   'order_dow': 3,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 29.0},
#  (2329, 3): {'order_id': 2423804,
#   'user_id': 2329,
#   'order_by_user_sequence': 3,
#   'order_dow': 0,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 11.0},
#  (2329, 4): {'order_id': 2101196,
#   'user_id': 2329,
#   'order_by_user_sequence': 4,
#   'order_dow': 0,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 7.0},
#  (2329, 5): {'order_id': 34741,
#   'user_id': 2329,
#   'order_by_user_sequence': 5,
#   'order_dow': 3,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 10.0},
#  (2329, 6): {'order_id': 694635,
#   'user_id': 2329,
#   'order_by_user_sequence': 6,
#   'order_dow': 3,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 14.0},
#  (2329, 7): {'order_id': 1481950,
#   'user_id': 2329,
#   'order_by_user_sequence': 7,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 30.0},
#  (2329, 8): {'order_id': 368627,
#   'user_id': 2329,
#   'order_by_user_sequence': 8,
#   'order_dow': 4,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 27.0},
#  (2329, 9): {'order_id': 1541832,
#   'user_id': 2329,
#   'order_by_user_sequence': 9,
#   'order_dow': 5,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 30.0},
#  (2329, 10): {'order_id': 1541832,
#   'user_id': 2329,
#   'order_by_user_sequence': 10,
#   'order_dow': 5,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 30.0},
#  (2348, 1): {'order_id': 3292772,
#   'user_id': 2348,
#   'order_by_user_sequence': 1,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': -1.0},
#  (2348, 2): {'order_id': 2795461,
#   'user_id': 2348,
#   'order_by_user_sequence': 2,
#   'order_dow': 0,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 30.0},
#  (2348, 3): {'order_id': 653496,
#   'user_id': 2348,
#   'order_by_user_sequence': 3,
#   'order_dow': 4,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 18.0},
#  (2348, 4): {'order_id': 1678449,
#   'user_id': 2348,
#   'order_by_user_sequence': 4,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 7.0},
#  (2348, 5): {'order_id': 1678449,
#   'user_id': 2348,
#   'order_by_user_sequence': 5,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 7.0},
#  (2592, 1): {'order_id': 454428,
#   'user_id': 2592,
#   'order_by_user_sequence': 1,
#   'order_dow': 4,
#   'order_hour_of_day': 21,
#   'days_since_prior_order': -1.0},
#  (2592, 2): {'order_id': 3063714,
#   'user_id': 2592,
#   'order_by_user_sequence': 2,
#   'order_dow': 0,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 10.0},
#  (2592, 3): {'order_id': 2858938,
#   'user_id': 2592,
#   'order_by_user_sequence': 3,
#   'order_dow': 0,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 14.0},
#  (2592, 4): {'order_id': 641324,
#   'user_id': 2592,
#   'order_by_user_sequence': 4,
#   'order_dow': 3,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 10.0},
#  (2592, 5): {'order_id': 2178191,
#   'user_id': 2592,
#   'order_by_user_sequence': 5,
#   'order_dow': 5,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 23.0},
#  (2592, 6): {'order_id': 1974813,
#   'user_id': 2592,
#   'order_by_user_sequence': 6,
#   'order_dow': 4,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 27.0},
#  (2592, 7): {'order_id': 3147000,
#   'user_id': 2592,
#   'order_by_user_sequence': 7,
#   'order_dow': 0,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 17.0},
#  (2592, 8): {'order_id': 1019406,
#   'user_id': 2592,
#   'order_by_user_sequence': 8,
#   'order_dow': 3,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 17.0},
#  (2592, 9): {'order_id': 429131,
#   'user_id': 2592,
#   'order_by_user_sequence': 9,
#   'order_dow': 0,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 11.0},
#  (2592, 10): {'order_id': 1875866,
#   'user_id': 2592,
#   'order_by_user_sequence': 10,
#   'order_dow': 0,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (2592, 11): {'order_id': 1493371,
#   'user_id': 2592,
#   'order_by_user_sequence': 11,
#   'order_dow': 0,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 14.0},
#  (2592, 12): {'order_id': 1123033,
#   'user_id': 2592,
#   'order_by_user_sequence': 12,
#   'order_dow': 0,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 30.0},
#  (2592, 13): {'order_id': 1817324,
#   'user_id': 2592,
#   'order_by_user_sequence': 13,
#   'order_dow': 3,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 10.0},
#  (2592, 14): {'order_id': 3389050,
#   'user_id': 2592,
#   'order_by_user_sequence': 14,
#   'order_dow': 5,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 9.0},
#  (2592, 15): {'order_id': 1811429,
#   'user_id': 2592,
#   'order_by_user_sequence': 15,
#   'order_dow': 0,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 23.0},
#  (2592, 16): {'order_id': 2443512,
#   'user_id': 2592,
#   'order_by_user_sequence': 16,
#   'order_dow': 2,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 16.0},
#  (2592, 17): {'order_id': 1014709,
#   'user_id': 2592,
#   'order_by_user_sequence': 17,
#   'order_dow': 1,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 6.0},
#  (2592, 18): {'order_id': 1782423,
#   'user_id': 2592,
#   'order_by_user_sequence': 18,
#   'order_dow': 0,
#   'order_hour_of_day': 22,
#   'days_since_prior_order': 6.0},
#  (2592, 19): {'order_id': 3308188,
#   'user_id': 2592,
#   'order_by_user_sequence': 19,
#   'order_dow': 2,
#   'order_hour_of_day': 22,
#   'days_since_prior_order': 16.0},
#  (2592, 20): {'order_id': 3204367,
#   'user_id': 2592,
#   'order_by_user_sequence': 20,
#   'order_dow': 6,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 11.0},
#  (2592, 21): {'order_id': 1813327,
#   'user_id': 2592,
#   'order_by_user_sequence': 21,
#   'order_dow': 6,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 7.0},
#  (2592, 22): {'order_id': 622902,
#   'user_id': 2592,
#   'order_by_user_sequence': 22,
#   'order_dow': 6,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (2592, 23): {'order_id': 827153,
#   'user_id': 2592,
#   'order_by_user_sequence': 23,
#   'order_dow': 1,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 9.0},
#  (2592, 24): {'order_id': 192974,
#   'user_id': 2592,
#   'order_by_user_sequence': 24,
#   'order_dow': 2,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 8.0},
#  (2592, 25): {'order_id': 1244565,
#   'user_id': 2592,
#   'order_by_user_sequence': 25,
#   'order_dow': 0,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 5.0},
#  (2592, 26): {'order_id': 1285599,
#   'user_id': 2592,
#   'order_by_user_sequence': 26,
#   'order_dow': 0,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 7.0},
#  (2592, 27): {'order_id': 1528183,
#   'user_id': 2592,
#   'order_by_user_sequence': 27,
#   'order_dow': 5,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 5.0},
#  (2592, 28): {'order_id': 701460,
#   'user_id': 2592,
#   'order_by_user_sequence': 28,
#   'order_dow': 6,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 8.0},
#  (2592, 29): {'order_id': 1078036,
#   'user_id': 2592,
#   'order_by_user_sequence': 29,
#   'order_dow': 6,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 14.0},
#  (2592, 30): {'order_id': 1078036,
#   'user_id': 2592,
#   'order_by_user_sequence': 30,
#   'order_dow': 6,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 14.0},
#  (2736, 1): {'order_id': 3068106,
#   'user_id': 2736,
#   'order_by_user_sequence': 1,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': -1.0},
#  (2736, 2): {'order_id': 2404006,
#   'user_id': 2736,
#   'order_by_user_sequence': 2,
#   'order_dow': 3,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 5.0},
#  (2736, 3): {'order_id': 3355599,
#   'user_id': 2736,
#   'order_by_user_sequence': 3,
#   'order_dow': 4,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 8.0},
#  (2736, 4): {'order_id': 2956590,
#   'user_id': 2736,
#   'order_by_user_sequence': 4,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 7.0},
#  (2736, 5): {'order_id': 1450526,
#   'user_id': 2736,
#   'order_by_user_sequence': 5,
#   'order_dow': 5,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 8.0},
#  (2736, 6): {'order_id': 514778,
#   'user_id': 2736,
#   'order_by_user_sequence': 6,
#   'order_dow': 1,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 3.0},
#  (2736, 7): {'order_id': 946435,
#   'user_id': 2736,
#   'order_by_user_sequence': 7,
#   'order_dow': 2,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 1.0},
#  (2736, 8): {'order_id': 2770713,
#   'user_id': 2736,
#   'order_by_user_sequence': 8,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 2.0},
#  (2736, 9): {'order_id': 1115713,
#   'user_id': 2736,
#   'order_by_user_sequence': 9,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 8.0},
#  (2736, 10): {'order_id': 3089923,
#   'user_id': 2736,
#   'order_by_user_sequence': 10,
#   'order_dow': 4,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 6.0},
#  (2736, 11): {'order_id': 2925545,
#   'user_id': 2736,
#   'order_by_user_sequence': 11,
#   'order_dow': 5,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 15.0},
#  (2736, 12): {'order_id': 1207550,
#   'user_id': 2736,
#   'order_by_user_sequence': 12,
#   'order_dow': 4,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 30.0},
#  (2736, 13): {'order_id': 3301086,
#   'user_id': 2736,
#   'order_by_user_sequence': 13,
#   'order_dow': 2,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 26.0},
#  (2736, 14): {'order_id': 3011423,
#   'user_id': 2736,
#   'order_by_user_sequence': 14,
#   'order_dow': 1,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 30.0},
#  (2736, 15): {'order_id': 2273681,
#   'user_id': 2736,
#   'order_by_user_sequence': 15,
#   'order_dow': 1,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 14.0},
#  (2736, 16): {'order_id': 2333988,
#   'user_id': 2736,
#   'order_by_user_sequence': 16,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 21.0},
#  (2736, 17): {'order_id': 127062,
#   'user_id': 2736,
#   'order_by_user_sequence': 17,
#   'order_dow': 2,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 22.0},
#  (2736, 18): {'order_id': 127062,
#   'user_id': 2736,
#   'order_by_user_sequence': 18,
#   'order_dow': 2,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 22.0},
#  (3443, 1): {'order_id': 1582723,
#   'user_id': 3443,
#   'order_by_user_sequence': 1,
#   'order_dow': 1,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': -1.0},
#  (3443, 2): {'order_id': 153503,
#   'user_id': 3443,
#   'order_by_user_sequence': 2,
#   'order_dow': 1,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 14.0},
#  (3443, 3): {'order_id': 1648409,
#   'user_id': 3443,
#   'order_by_user_sequence': 3,
#   'order_dow': 2,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 15.0},
#  (3443, 4): {'order_id': 465367,
#   'user_id': 3443,
#   'order_by_user_sequence': 4,
#   'order_dow': 0,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 26.0},
#  (3443, 5): {'order_id': 174986,
#   'user_id': 3443,
#   'order_by_user_sequence': 5,
#   'order_dow': 6,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 6.0},
#  (3443, 6): {'order_id': 1223887,
#   'user_id': 3443,
#   'order_by_user_sequence': 6,
#   'order_dow': 4,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 12.0},
#  (3443, 7): {'order_id': 1266675,
#   'user_id': 3443,
#   'order_by_user_sequence': 7,
#   'order_dow': 2,
#   'order_hour_of_day': 21,
#   'days_since_prior_order': 26.0},
#  (3443, 8): {'order_id': 1868232,
#   'user_id': 3443,
#   'order_by_user_sequence': 8,
#   'order_dow': 0,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 12.0},
#  (3443, 9): {'order_id': 1843266,
#   'user_id': 3443,
#   'order_by_user_sequence': 9,
#   'order_dow': 6,
#   'order_hour_of_day': 0,
#   'days_since_prior_order': 30.0},
#  (3443, 10): {'order_id': 2677855,
#   'user_id': 3443,
#   'order_by_user_sequence': 10,
#   'order_dow': 6,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 30.0},
#  (3443, 11): {'order_id': 3078469,
#   'user_id': 3443,
#   'order_by_user_sequence': 11,
#   'order_dow': 5,
#   'order_hour_of_day': 0,
#   'days_since_prior_order': 6.0},
#  (3443, 12): {'order_id': 3366168,
#   'user_id': 3443,
#   'order_by_user_sequence': 12,
#   'order_dow': 6,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 22.0},
#  (3443, 13): {'order_id': 3349056,
#   'user_id': 3443,
#   'order_by_user_sequence': 13,
#   'order_dow': 3,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 25.0},
#  (3443, 14): {'order_id': 104960,
#   'user_id': 3443,
#   'order_by_user_sequence': 14,
#   'order_dow': 3,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 28.0},
#  (3443, 15): {'order_id': 2001951,
#   'user_id': 3443,
#   'order_by_user_sequence': 15,
#   'order_dow': 2,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 13.0},
#  (3443, 16): {'order_id': 2655937,
#   'user_id': 3443,
#   'order_by_user_sequence': 16,
#   'order_dow': 1,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 20.0},
#  (3443, 17): {'order_id': 2655937,
#   'user_id': 3443,
#   'order_by_user_sequence': 17,
#   'order_dow': 1,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 20.0},
#  (3980, 1): {'order_id': 3376355,
#   'user_id': 3980,
#   'order_by_user_sequence': 1,
#   'order_dow': 3,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': -1.0},
#  (3980, 2): {'order_id': 2042748,
#   'user_id': 3980,
#   'order_by_user_sequence': 2,
#   'order_dow': 1,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 19.0},
#  (3980, 3): {'order_id': 1954204,
#   'user_id': 3980,
#   'order_by_user_sequence': 3,
#   'order_dow': 6,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 5.0},
#  (3980, 4): {'order_id': 1921759,
#   'user_id': 3980,
#   'order_by_user_sequence': 4,
#   'order_dow': 2,
#   'order_hour_of_day': 22,
#   'days_since_prior_order': 17.0},
#  (3980, 5): {'order_id': 2484941,
#   'user_id': 3980,
#   'order_by_user_sequence': 5,
#   'order_dow': 0,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 5.0},
#  (3980, 6): {'order_id': 2104377,
#   'user_id': 3980,
#   'order_by_user_sequence': 6,
#   'order_dow': 0,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 7.0},
#  (3980, 7): {'order_id': 48026,
#   'user_id': 3980,
#   'order_by_user_sequence': 7,
#   'order_dow': 0,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 14.0},
#  (3980, 8): {'order_id': 958640,
#   'user_id': 3980,
#   'order_by_user_sequence': 8,
#   'order_dow': 6,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 6.0},
#  (3980, 9): {'order_id': 521030,
#   'user_id': 3980,
#   'order_by_user_sequence': 9,
#   'order_dow': 1,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 2.0},
#  (3980, 10): {'order_id': 620211,
#   'user_id': 3980,
#   'order_by_user_sequence': 10,
#   'order_dow': 0,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 6.0},
#  (3980, 11): {'order_id': 1161209,
#   'user_id': 3980,
#   'order_by_user_sequence': 11,
#   'order_dow': 6,
#   'order_hour_of_day': 21,
#   'days_since_prior_order': 13.0},
#  (3980, 12): {'order_id': 437963,
#   'user_id': 3980,
#   'order_by_user_sequence': 12,
#   'order_dow': 4,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 5.0},
#  (3980, 13): {'order_id': 1637913,
#   'user_id': 3980,
#   'order_by_user_sequence': 13,
#   'order_dow': 1,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 4.0},
#  (3980, 14): {'order_id': 1512592,
#   'user_id': 3980,
#   'order_by_user_sequence': 14,
#   'order_dow': 3,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 2.0},
#  (3980, 15): {'order_id': 2505448,
#   'user_id': 3980,
#   'order_by_user_sequence': 15,
#   'order_dow': 6,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 17.0},
#  (3980, 16): {'order_id': 1641387,
#   'user_id': 3980,
#   'order_by_user_sequence': 16,
#   'order_dow': 6,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 21.0},
#  (3980, 17): {'order_id': 3140010,
#   'user_id': 3980,
#   'order_by_user_sequence': 17,
#   'order_dow': 2,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 10.0},
#  (3980, 18): {'order_id': 3384308,
#   'user_id': 3980,
#   'order_by_user_sequence': 18,
#   'order_dow': 1,
#   'order_hour_of_day': 22,
#   'days_since_prior_order': 6.0},
#  (3980, 19): {'order_id': 2043486,
#   'user_id': 3980,
#   'order_by_user_sequence': 19,
#   'order_dow': 5,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': 11.0},
#  (3980, 20): {'order_id': 2419527,
#   'user_id': 3980,
#   'order_by_user_sequence': 20,
#   'order_dow': 2,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 18.0},
#  (3980, 21): {'order_id': 184088,
#   'user_id': 3980,
#   'order_by_user_sequence': 21,
#   'order_dow': 5,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 3.0},
#  (3980, 22): {'order_id': 2652148,
#   'user_id': 3980,
#   'order_by_user_sequence': 22,
#   'order_dow': 4,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 13.0},
#  (3980, 23): {'order_id': 2132419,
#   'user_id': 3980,
#   'order_by_user_sequence': 23,
#   'order_dow': 6,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 9.0},
#  (3980, 24): {'order_id': 3152436,
#   'user_id': 3980,
#   'order_by_user_sequence': 24,
#   'order_dow': 1,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 2.0},
#  (3980, 25): {'order_id': 392836,
#   'user_id': 3980,
#   'order_by_user_sequence': 25,
#   'order_dow': 2,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 8.0},
#  (3980, 26): {'order_id': 1377502,
#   'user_id': 3980,
#   'order_by_user_sequence': 26,
#   'order_dow': 3,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 22.0},
#  (3980, 27): {'order_id': 2392583,
#   'user_id': 3980,
#   'order_by_user_sequence': 27,
#   'order_dow': 0,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 4.0},
#  (3980, 28): {'order_id': 2594499,
#   'user_id': 3980,
#   'order_by_user_sequence': 28,
#   'order_dow': 5,
#   'order_hour_of_day': 21,
#   'days_since_prior_order': 5.0},
#  (3980, 29): {'order_id': 895414,
#   'user_id': 3980,
#   'order_by_user_sequence': 29,
#   'order_dow': 0,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 9.0},
#  (3980, 30): {'order_id': 210122,
#   'user_id': 3980,
#   'order_by_user_sequence': 30,
#   'order_dow': 3,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 17.0},
#  (3980, 31): {'order_id': 1488230,
#   'user_id': 3980,
#   'order_by_user_sequence': 31,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 16.0},
#  (3980, 32): {'order_id': 2239240,
#   'user_id': 3980,
#   'order_by_user_sequence': 32,
#   'order_dow': 3,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 5.0},
#  (3980, 33): {'order_id': 1493272,
#   'user_id': 3980,
#   'order_by_user_sequence': 33,
#   'order_dow': 3,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 14.0},
#  (3980, 34): {'order_id': 933004,
#   'user_id': 3980,
#   'order_by_user_sequence': 34,
#   'order_dow': 3,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 7.0},
#  (3980, 35): {'order_id': 389331,
#   'user_id': 3980,
#   'order_by_user_sequence': 35,
#   'order_dow': 1,
#   'order_hour_of_day': 19,
#   'days_since_prior_order': 5.0},
#  (3980, 36): {'order_id': 67157,
#   'user_id': 3980,
#   'order_by_user_sequence': 36,
#   'order_dow': 0,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 6.0},
#  (3980, 37): {'order_id': 1043848,
#   'user_id': 3980,
#   'order_by_user_sequence': 37,
#   'order_dow': 2,
#   'order_hour_of_day': 20,
#   'days_since_prior_order': 9.0},
#  (3980, 38): {'order_id': 2692484,
#   'user_id': 3980,
#   'order_by_user_sequence': 38,
#   'order_dow': 6,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 4.0},
#  (3980, 39): {'order_id': 2822405,
#   'user_id': 3980,
#   'order_by_user_sequence': 39,
#   'order_dow': 4,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 5.0},
#  (3980, 40): {'order_id': 2822405,
#   'user_id': 3980,
#   'order_by_user_sequence': 40,
#   'order_dow': 4,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 5.0},
#  (4150, 1): {'order_id': 3124367,
#   'user_id': 4150,
#   'order_by_user_sequence': 1,
#   'order_dow': 2,
# ...
#  (13334, 23): {'order_id': 2799518,
#   'user_id': 13334,
#   'order_by_user_sequence': 23,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (13334, 24): {'order_id': 2275537,
#   'user_id': 13334,
#   'order_by_user_sequence': 24,
#   'order_dow': 4,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 6.0},
#  (13334, 25): {'order_id': 3373955,
#   'user_id': 13334,
#   'order_by_user_sequence': 25,
#   'order_dow': 4,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 0.0},
#  (13334, 26): {'order_id': 690166,
#   'user_id': 13334,
#   'order_by_user_sequence': 26,
#   'order_dow': 5,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 8.0},
#  (13334, 27): {'order_id': 2773690,
#   'user_id': 13334,
#   'order_by_user_sequence': 27,
#   'order_dow': 3,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 5.0},
#  (13334, 28): {'order_id': 3176702,
#   'user_id': 13334,
#   'order_by_user_sequence': 28,
#   'order_dow': 5,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 2.0},
#  (13334, 29): {'order_id': 831051,
#   'user_id': 13334,
#   'order_by_user_sequence': 29,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 3.0},
#  (13334, 30): {'order_id': 596725,
#   'user_id': 13334,
#   'order_by_user_sequence': 30,
#   'order_dow': 5,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 4.0},
#  (13334, 31): {'order_id': 319142,
#   'user_id': 13334,
#   'order_by_user_sequence': 31,
#   'order_dow': 2,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (13334, 32): {'order_id': 3063756,
#   'user_id': 13334,
#   'order_by_user_sequence': 32,
#   'order_dow': 4,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 2.0},
#  (13334, 33): {'order_id': 1268083,
#   'user_id': 13334,
#   'order_by_user_sequence': 33,
#   'order_dow': 1,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 4.0},
#  (13334, 34): {'order_id': 83420,
#   'user_id': 13334,
#   'order_by_user_sequence': 34,
#   'order_dow': 3,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 2.0},
#  (13334, 35): {'order_id': 1954438,
#   'user_id': 13334,
#   'order_by_user_sequence': 35,
#   'order_dow': 2,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 6.0},
#  (13334, 36): {'order_id': 2259412,
#   'user_id': 13334,
#   'order_by_user_sequence': 36,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 3.0},
#  (13334, 37): {'order_id': 1618544,
#   'user_id': 13334,
#   'order_by_user_sequence': 37,
#   'order_dow': 3,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 5.0},
#  (13334, 38): {'order_id': 1267279,
#   'user_id': 13334,
#   'order_by_user_sequence': 38,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 2.0},
#  (13334, 39): {'order_id': 1313188,
#   'user_id': 13334,
#   'order_by_user_sequence': 39,
#   'order_dow': 2,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 4.0},
#  (13334, 40): {'order_id': 975304,
#   'user_id': 13334,
#   'order_by_user_sequence': 40,
#   'order_dow': 4,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 9.0},
#  (13334, 41): {'order_id': 1543273,
#   'user_id': 13334,
#   'order_by_user_sequence': 41,
#   'order_dow': 2,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 5.0},
#  (13334, 42): {'order_id': 2323400,
#   'user_id': 13334,
#   'order_by_user_sequence': 42,
#   'order_dow': 4,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 2.0},
#  (13334, 43): {'order_id': 2612209,
#   'user_id': 13334,
#   'order_by_user_sequence': 43,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 1.0},
#  (13334, 44): {'order_id': 1515139,
#   'user_id': 13334,
#   'order_by_user_sequence': 44,
#   'order_dow': 1,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 3.0},
#  (13334, 45): {'order_id': 2761572,
#   'user_id': 13334,
#   'order_by_user_sequence': 45,
#   'order_dow': 1,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 0.0},
#  (13334, 46): {'order_id': 2620118,
#   'user_id': 13334,
#   'order_by_user_sequence': 46,
#   'order_dow': 3,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 2.0},
#  (13334, 47): {'order_id': 1438608,
#   'user_id': 13334,
#   'order_by_user_sequence': 47,
#   'order_dow': 4,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 1.0},
#  (13334, 48): {'order_id': 1635346,
#   'user_id': 13334,
#   'order_by_user_sequence': 48,
#   'order_dow': 5,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 1.0},
#  (13334, 49): {'order_id': 2170556,
#   'user_id': 13334,
#   'order_by_user_sequence': 49,
#   'order_dow': 2,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 4.0},
#  (13334, 50): {'order_id': 2276667,
#   'user_id': 13334,
#   'order_by_user_sequence': 50,
#   'order_dow': 5,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 3.0},
#  (13334, 51): {'order_id': 297472,
#   'user_id': 13334,
#   'order_by_user_sequence': 51,
#   'order_dow': 5,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 7.0},
#  (13334, 52): {'order_id': 1191410,
#   'user_id': 13334,
#   'order_by_user_sequence': 52,
#   'order_dow': 2,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (13334, 53): {'order_id': 2067718,
#   'user_id': 13334,
#   'order_by_user_sequence': 53,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 3.0},
#  (13334, 54): {'order_id': 2288412,
#   'user_id': 13334,
#   'order_by_user_sequence': 54,
#   'order_dow': 2,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 4.0},
#  (13334, 55): {'order_id': 788585,
#   'user_id': 13334,
#   'order_by_user_sequence': 55,
#   'order_dow': 4,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 9.0},
#  (13334, 56): {'order_id': 437042,
#   'user_id': 13334,
#   'order_by_user_sequence': 56,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 4.0},
#  (13334, 57): {'order_id': 1968658,
#   'user_id': 13334,
#   'order_by_user_sequence': 57,
#   'order_dow': 2,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 1.0},
#  (13334, 58): {'order_id': 3043800,
#   'user_id': 13334,
#   'order_by_user_sequence': 58,
#   'order_dow': 1,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 6.0},
#  (13334, 59): {'order_id': 1120796,
#   'user_id': 13334,
#   'order_by_user_sequence': 59,
#   'order_dow': 2,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 1.0},
#  (13334, 60): {'order_id': 2444076,
#   'user_id': 13334,
#   'order_by_user_sequence': 60,
#   'order_dow': 1,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 6.0},
#  (13334, 61): {'order_id': 2458686,
#   'user_id': 13334,
#   'order_by_user_sequence': 61,
#   'order_dow': 3,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 2.0},
#  (13334, 62): {'order_id': 1570032,
#   'user_id': 13334,
#   'order_by_user_sequence': 62,
#   'order_dow': 1,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 12.0},
#  (13334, 63): {'order_id': 1221915,
#   'user_id': 13334,
#   'order_by_user_sequence': 63,
#   'order_dow': 5,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 4.0},
#  (13334, 64): {'order_id': 2113742,
#   'user_id': 13334,
#   'order_by_user_sequence': 64,
#   'order_dow': 3,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 5.0},
#  (13334, 65): {'order_id': 2540930,
#   'user_id': 13334,
#   'order_by_user_sequence': 65,
#   'order_dow': 5,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 2.0},
#  (13334, 66): {'order_id': 2400018,
#   'user_id': 13334,
#   'order_by_user_sequence': 66,
#   'order_dow': 3,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 5.0},
#  (13334, 67): {'order_id': 2030087,
#   'user_id': 13334,
#   'order_by_user_sequence': 67,
#   'order_dow': 5,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 2.0},
#  (13334, 68): {'order_id': 6779,
#   'user_id': 13334,
#   'order_by_user_sequence': 68,
#   'order_dow': 1,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 3.0},
#  (13334, 69): {'order_id': 1676154,
#   'user_id': 13334,
#   'order_by_user_sequence': 69,
#   'order_dow': 5,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 4.0},
#  (13334, 70): {'order_id': 2143944,
#   'user_id': 13334,
#   'order_by_user_sequence': 70,
#   'order_dow': 1,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 10.0},
#  (13334, 71): {'order_id': 2028983,
#   'user_id': 13334,
#   'order_by_user_sequence': 71,
#   'order_dow': 4,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 3.0},
#  (13334, 72): {'order_id': 2313570,
#   'user_id': 13334,
#   'order_by_user_sequence': 72,
#   'order_dow': 2,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 5.0},
#  (13334, 73): {'order_id': 1335414,
#   'user_id': 13334,
#   'order_by_user_sequence': 73,
#   'order_dow': 4,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 2.0},
#  (13334, 74): {'order_id': 300524,
#   'user_id': 13334,
#   'order_by_user_sequence': 74,
#   'order_dow': 5,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 8.0},
#  (13334, 75): {'order_id': 2075939,
#   'user_id': 13334,
#   'order_by_user_sequence': 75,
#   'order_dow': 5,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 7.0},
#  (13334, 76): {'order_id': 1773831,
#   'user_id': 13334,
#   'order_by_user_sequence': 76,
#   'order_dow': 5,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 7.0},
#  (13334, 77): {'order_id': 2368398,
#   'user_id': 13334,
#   'order_by_user_sequence': 77,
#   'order_dow': 2,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 4.0},
#  (13334, 78): {'order_id': 2522892,
#   'user_id': 13334,
#   'order_by_user_sequence': 78,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 3.0},
#  (13334, 79): {'order_id': 182008,
#   'user_id': 13334,
#   'order_by_user_sequence': 79,
#   'order_dow': 3,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 5.0},
#  (13334, 80): {'order_id': 2639812,
#   'user_id': 13334,
#   'order_by_user_sequence': 80,
#   'order_dow': 2,
#   'order_hour_of_day': 9,
#   'days_since_prior_order': 6.0},
#  (13334, 81): {'order_id': 522038,
#   'user_id': 13334,
#   'order_by_user_sequence': 81,
#   'order_dow': 1,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 13.0},
#  (13334, 82): {'order_id': 2279460,
#   'user_id': 13334,
#   'order_by_user_sequence': 82,
#   'order_dow': 3,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 2.0},
#  (13334, 83): {'order_id': 618440,
#   'user_id': 13334,
#   'order_by_user_sequence': 83,
#   'order_dow': 5,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 2.0},
#  (13334, 84): {'order_id': 25640,
#   'user_id': 13334,
#   'order_by_user_sequence': 84,
#   'order_dow': 1,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 10.0},
#  (13334, 85): {'order_id': 2555064,
#   'user_id': 13334,
#   'order_by_user_sequence': 85,
#   'order_dow': 4,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 3.0},
#  (13334, 86): {'order_id': 2555064,
#   'user_id': 13334,
#   'order_by_user_sequence': 86,
#   'order_dow': 4,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 3.0},
#  (13908, 1): {'order_id': 1253668,
#   'user_id': 13908,
#   'order_by_user_sequence': 1,
#   'order_dow': 5,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': -1.0},
#  (13908, 2): {'order_id': 1334611,
#   'user_id': 13908,
#   'order_by_user_sequence': 2,
#   'order_dow': 6,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 22.0},
#  (13908, 3): {'order_id': 2615865,
#   'user_id': 13908,
#   'order_by_user_sequence': 3,
#   'order_dow': 1,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 16.0},
#  (13908, 4): {'order_id': 324888,
#   'user_id': 13908,
#   'order_by_user_sequence': 4,
#   'order_dow': 5,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 25.0},
#  (13908, 5): {'order_id': 3229240,
#   'user_id': 13908,
#   'order_by_user_sequence': 5,
#   'order_dow': 5,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 30.0},
#  (13908, 6): {'order_id': 969100,
#   'user_id': 13908,
#   'order_by_user_sequence': 6,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 30.0},
#  (13908, 7): {'order_id': 969100,
#   'user_id': 13908,
#   'order_by_user_sequence': 7,
#   'order_dow': 5,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 30.0},
#  (14258, 1): {'order_id': 1200239,
#   'user_id': 14258,
#   'order_by_user_sequence': 1,
#   'order_dow': 6,
#   'order_hour_of_day': 17,
#   'days_since_prior_order': -1.0},
#  (14258, 2): {'order_id': 499533,
#   'user_id': 14258,
#   'order_by_user_sequence': 2,
#   'order_dow': 0,
#   'order_hour_of_day': 18,
#   'days_since_prior_order': 29.0},
#  (14258, 3): {'order_id': 3087971,
#   'user_id': 14258,
#   'order_by_user_sequence': 3,
#   'order_dow': 0,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 21.0},
#  (14258, 4): {'order_id': 354743,
#   'user_id': 14258,
#   'order_by_user_sequence': 4,
#   'order_dow': 0,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 7.0},
#  (14258, 5): {'order_id': 2721599,
#   'user_id': 14258,
#   'order_by_user_sequence': 5,
#   'order_dow': 0,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 14.0},
#  (14258, 6): {'order_id': 2157068,
#   'user_id': 14258,
#   'order_by_user_sequence': 6,
#   'order_dow': 6,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 6.0},
#  (14258, 7): {'order_id': 3087934,
#   'user_id': 14258,
#   'order_by_user_sequence': 7,
#   'order_dow': 0,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 8.0},
#  (14258, 8): {'order_id': 3103229,
#   'user_id': 14258,
#   'order_by_user_sequence': 8,
#   'order_dow': 6,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 6.0},
#  (14258, 9): {'order_id': 2827929,
#   'user_id': 14258,
#   'order_by_user_sequence': 9,
#   'order_dow': 2,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 17.0},
#  (14258, 10): {'order_id': 186683,
#   'user_id': 14258,
#   'order_by_user_sequence': 10,
#   'order_dow': 0,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 19.0},
#  (14258, 11): {'order_id': 1297978,
#   'user_id': 14258,
#   'order_by_user_sequence': 11,
#   'order_dow': 6,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 6.0},
#  (14258, 12): {'order_id': 1779078,
#   'user_id': 14258,
#   'order_by_user_sequence': 12,
#   'order_dow': 6,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 28.0},
#  (14258, 13): {'order_id': 2517133,
#   'user_id': 14258,
#   'order_by_user_sequence': 13,
#   'order_dow': 0,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': 8.0},
#  (14258, 14): {'order_id': 360021,
#   'user_id': 14258,
#   'order_by_user_sequence': 14,
#   'order_dow': 0,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 28.0},
#  (14258, 15): {'order_id': 1106810,
#   'user_id': 14258,
#   'order_by_user_sequence': 15,
#   'order_dow': 6,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 13.0},
#  (14258, 16): {'order_id': 835116,
#   'user_id': 14258,
#   'order_by_user_sequence': 16,
#   'order_dow': 1,
#   'order_hour_of_day': 16,
#   'days_since_prior_order': 30.0},
#  (14258, 17): {'order_id': 897072,
#   'user_id': 14258,
#   'order_by_user_sequence': 17,
#   'order_dow': 6,
#   'order_hour_of_day': 13,
#   'days_since_prior_order': 26.0},
#  (14258, 18): {'order_id': 83669,
#   'user_id': 14258,
#   'order_by_user_sequence': 18,
#   'order_dow': 0,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 29.0},
#  (14258, 19): {'order_id': 1232933,
#   'user_id': 14258,
#   'order_by_user_sequence': 19,
#   'order_dow': 6,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 20.0},
#  (14258, 20): {'order_id': 1143909,
#   'user_id': 14258,
#   'order_by_user_sequence': 20,
#   'order_dow': 0,
#   'order_hour_of_day': 14,
#   'days_since_prior_order': 8.0},
#  (14258, 21): {'order_id': 2839348,
#   'user_id': 14258,
#   'order_by_user_sequence': 21,
#   'order_dow': 6,
#   'order_hour_of_day': 10,
#   'days_since_prior_order': 13.0},
#  (14258, 22): {'order_id': 210109,
#   'user_id': 14258,
#   'order_by_user_sequence': 22,
#   'order_dow': 6,
#   'order_hour_of_day': 21,
#   'days_since_prior_order': 7.0},
#  (14258, 23): {'order_id': 210109,
#   'user_id': 14258,
#   'order_by_user_sequence': 23,
#   'order_dow': 6,
#   'order_hour_of_day': 21,
#   'days_since_prior_order': 7.0},
#  (14578, 1): {'order_id': 2198989,
#   'user_id': 14578,
#   'order_by_user_sequence': 1,
#   'order_dow': 2,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': -1.0},
#  (14578, 2): {'order_id': 2204007,
#   'user_id': 14578,
#   'order_by_user_sequence': 2,
#   'order_dow': 5,
#   'order_hour_of_day': 11,
#   'days_since_prior_order': 10.0},
#  ...}

# %%
# Create reorders_so_far column.
# Code I used with the practice user:

previous_round_items = set(df[df['reorders_so_far']==3][
    'product_name'])

grouped_by_product = df[df['reorders_so_far']==3].groupby(
    'product_name')['order_by_user_sequence']
df['keep'] = df.assign(min=grouped_by_product.transform(min))['min']

#for n in range (4,47):
    for order in range(7,101):
        items_this_order = set(products_reordered_each_order[order])
        reordered_this_iteration = set(
            previous_round_items.intersection(items_this_order))
        rows_to_change = df.loc[(df.loc[
        :,'order_by_user_sequence']==order) & (df.loc[
        :, 'reorders_so_far']==n-1) & (df['order_by_user_sequence']!=
        df['keep']) & (df.loc[:,'product_name'].isin(
        reordered_this_iteration))]
        df.loc[rows_to_change.index, 'reorders_so_far'] = n
    previous_round_items = set(df[df['reorders_so_far']==n][
        'product_name'])
    grouped_by_product = df[df['reorders_so_far']==n].groupby(
        'product_name')['order_by_user_sequence']
    df['keep'] = df.assign(min=grouped_by_product.transform(min))[
        'min']
# Out:
#   File "/var/folders/xz/sq63wkqx22q0t_hr7_1jfrhr0000gn/T/ipykernel_13227/1973831926.py", line 12
#     for order in range(7,101):
#     ^
# IndentationError: unexpected indent

# %%
# Create past_orders column & delete reorders_so_far
# Code I used to create past_orders with one user:

items_already_ordered_ntimes = set(df[df['past_orders']==2][
    'product_name'])
when_items_first_ordered = list(df.groupby('product_name')[
    'order_by_user_sequence'].idxmin())

#for n in range(2,47): 
    rows_npast = df[df['product_name'].isin(
    items_already_ordered_ntimes)]
    rows_npast = rows_npast[rows_npast['past_orders']==0]
    rows_npast = rows_npast.drop(when_items_first_ordered, axis=0, 
                             errors='ignore')
    when_reordered_ntimes = df[df['reorders_so_far']==n].set_index(
    'product_name').to_dict()['order_by_user_sequence']
    for prod, order in when_reordered_ntimes.items():
        ind_to_delete = rows_npast[(rows_npast['product_name']==prod) &
                                   (rows_npast[
                                       'order_by_user_sequence']
                                    >order)].index
        rows_npast = rows_npast.drop(ind_to_delete)
    df.loc[np.array(rows_npast.index),'past_orders'] = n
    items_already_ordered_ntimes = set(df[df['past_orders']==n][
        'product_name'])

# %%
# Engineer columns for product keywords

# %%
# Change format of dow, hour columns

# %%
# Save work done so far as new csv file

# %%
# Move to new notebook for encoding & standardizing remaining features
