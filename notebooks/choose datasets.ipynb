# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
#attempt at reading a csv file connected with former idea related to trans 
pd.read_csv('../data/project.ideas/trans.covid/2021_06JUN_04_TransNB_CovidDisparitiesGroup.original.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 #attempt at reading a csv file connected with former idea related to trans
# ----> 2 pd.read_csv('../data/project.ideas/trans.covid/2021_06JUN_04_TransNB_CovidDisparitiesGroup.original.csv')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
#attempt after saving with encoding utf-8
pd.read_csv('../data/project.ideas/trans.covid/2021_06JUN_04_TransNB_CovidDisparitiesGroup.utf8.csv')
# Out:
#       504b 0304 1400 0600 0800 0000 2100 7c6c
# 0     9816 6901 0000 a005 0000 1300 0802 5b43
# 1     6f6e 7465 6e74 5f54 7970 6573 5d2e 786d
# 2     6c20 a204 0228 a000 0200 0000 0000 0000
# 3     0000 0000 0000 0000 0000 0000 0000 0000
# 4     0000 0000 0000 0000 0000 0000 0000 0000
# ...                                       ...
# 7569  0006 0008 0000 0021 0020 080f 729b 0100
# 7570  0047 0300 0010 0000 0000 0000 0000 0000
# 7571  0000 0029 d301 0064 6f63 5072 6f70 732f
# 7572  6170 702e 786d 6c50 4b05 0600 0000 000d
# 7573         000d 005d 0300 00fa d501 0000 00
#
# [7574 rows x 1 columns]

# %%
#initial load of duolingo learner interaction
pd.read_csv('../data/project.ideas/duolingo/settles.acl16.learning_traces.13m.csv')
# Out:
#           p_recall   timestamp     delta user_id learning_language  \
# 0         1.000000  1362076081  27649635    u:FO                de
# 1         0.500000  1362076081  27649635    u:FO                de
# 2         1.000000  1362076081  27649635    u:FO                de
# 3         0.500000  1362076081  27649635    u:FO                de
# 4         1.000000  1362076081  27649635    u:FO                de
# ...            ...         ...       ...     ...               ...
# 12854221  0.800000  1363104897       368  u:i5D8                en
# 12854222  0.800000  1363104897       368  u:i5D8                en
# 12854223  1.000000  1363104897       368  u:i5D8                en
# 12854224  0.600000  1363104897       368  u:i5D8                en
# 12854225  0.666667  1363104897       368  u:i5D8                en
#
#          ui_language                         lexeme_id  \
# 0                 en  76390c1350a8dac31186187e2fe1e178
# ...

# %%
# initial load of sonoma county trans homelessness census data
pd.read_csv('../data/project.ideas/homelessness/query-8034011b3f8adbd765ee7dead7bb151d3e257a64-20220918-230456.csv')
# Out:
#                    :id  transgender_total  census_tract  year  \
# 0   row-mvry_3sbh~yvfs                  0        150304  2018
# 1   row-fi9p-6axp~axuy                  0        150305  2018
# 2   row-ipuq_ties_j7zu                  0        151000  2018
# 3   row-amvh.827p~5d33                  0        151307  2018
# 4   row-wz3z_rvc9_jxbe                  0        151308  2018
# ..                 ...                ...           ...   ...
# 95  row-dg2b_v7cp-snw3                  0        150901  2017
# 96  row-mnyq_dy94.qcn5                  0        153001  2018
# 97  row-w27i.wg79-s8jx                  0        152501  2017
# 98  row-8zez.x2js~ncpq                  0        153804  2017
# 99  row-5vta.d5tg~2jni                  0        152802  2017
#
#     :@computed_region_xw9s_pz78  location_1_city  male_total  female_total  \
# 0                           5.0              NaN          10             4
# ...
